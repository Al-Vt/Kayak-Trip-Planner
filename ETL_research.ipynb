# %%
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
import os

# %%
import subprocess
result = subprocess.run(['chcp'], shell=True, capture_output=True, text=True)
print(result.stdout)
# Out:
# Exception in thread Thread-3 (_readerthread):
# Traceback (most recent call last):
#   File "c:\Users\axelv\anaconda3\envs\python_3_11\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "c:\Users\axelv\anaconda3\envs\python_3_11\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\axelv\anaconda3\envs\python_3_11\Lib\subprocess.py", line 1599, in _readerthread
#     buffer.append(fh.read())
#                   ^^^^^^^^^
#   File "<frozen codecs>", line 322, in decode
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 20: invalid start byte
# None

# %%
import os
os.environ["PYTHONIOENCODING"] = "utf-8"
os.environ["PGCLIENTENCODING"] = "utf-8"

# Force Windows code page
import ctypes
ctypes.windll.kernel32.SetConsoleCP(65001)
ctypes.windll.kernel32.SetConsoleOutputCP(65001)

import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="kayak_dw",
    user="kayak",
    password="kayak"
)
print("OK")
conn.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 12
#       8 ctypes.windll.kernel32.SetConsoleOutputCP(65001)
#      10 import psycopg2
# ---> 12 conn = psycopg2.connect(
#      13     host="localhost",
#      14     port=5432,
#      15     database="kayak_dw",
#      16     user="kayak",
#      17     password="kayak"
#      18 )
#      19 print("OK")
#      20 conn.close()
#
# File c:\Users\axelv\anaconda3\envs\python_3_11\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# ...

# %%
import psycopg2
import sys

print(sys.getdefaultencoding())
print(sys.getfilesystemencoding())

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="kayak_dw",
    user="kayak",
    password="kayak"
)
# Out:
# utf-8
# utf-8
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 7
#       4 print(sys.getdefaultencoding())
#       5 print(sys.getfilesystemencoding())
# ----> 7 conn = psycopg2.connect(
#       8     host="localhost",
#       9     port=5432,
#      10     database="kayak_dw",
#      11     user="kayak",
#      12     password="kayak"
#      13 )
#
# File c:\Users\axelv\anaconda3\envs\python_3_11\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# ...

# %% [markdown]
# The problem stems from Windows; a word needs an accent because my Windows is in French. That's why we're bypassing the problem by using Airflow. This way, we'll use a Linux container, where this kind of issue doesn't occur.
